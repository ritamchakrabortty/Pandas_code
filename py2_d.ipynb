# %%
import pandas as pd
df = pd.read_csv('/content/testset.csv')

df
# Out:
#           datetime_utc  _conds   _dewptm   _fog   _hail   _heatindexm   _hum  \
# 0       19961101-11:00   Smoke       9.0      0       0           NaN   27.0
# 1       19961101-12:00   Smoke      10.0      0       0           NaN   32.0
# 2       19961101-13:00   Smoke      11.0      0       0           NaN   44.0
# 3       19961101-14:00   Smoke      10.0      0       0           NaN   41.0
# 4       19961101-16:00   Smoke      11.0      0       0           NaN   47.0
# ...                ...     ...       ...    ...     ...           ...    ...
# 100985  20170424-06:00    Haze      17.0      0       0           NaN   25.0
# 100986  20170424-09:00    Haze      14.0      0       0           NaN   16.0
# 100987  20170424-12:00    Haze      12.0      0       0           NaN   14.0
# 100988  20170424-15:00    Haze      15.0      0       0           NaN   27.0
# 100989  20170424-18:00    Haze      15.0      0       0           NaN   30.0
#
# ...

# %%
df2 = pd.read_csv('/content/weather_data.csv')
df2
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df2['temperature'].max()
# Out:
# 35

# %%
df2['day'][df2['event']=='Sunny']
# Out:
# 1    1/2/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
df2['windspeed'].mean()
# Out:
# 4.666666666666667

# %%
df.fillna(0,inplace=True)
df[' _wspdm'].mean()
# Out:
# 7.499180116843252

# %%
df.describe()
# Out:
#             _dewptm           _fog          _hail    _heatindexm  \
# count  100990.00000  100990.000000  100990.000000  100990.000000
# mean       15.64441       0.069690       0.000129      10.292362
# std         7.14364       0.254625       0.011345      16.379004
# min       -24.00000       0.000000       0.000000       0.000000
# 25%        10.00000       0.000000       0.000000       0.000000
# 50%        15.00000       0.000000       0.000000       0.000000
# 75%        22.00000       0.000000       0.000000      30.100000
# max        75.00000       1.000000       1.000000      73.600000
#
#                 _hum   _precipm    _pressurem          _rain          _snow  \
# count  100990.000000   100990.0  1.009900e+05  100990.000000  100990.000000
# mean       57.475404        0.0  1.927892e+03       0.026260       0.000010
# std        24.238610        0.0  3.180127e+05       0.159908       0.003147
# ...

# %%
df2[df2.temperature>=30]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df[df[' _tempm']>=32]
# Out:
#           datetime_utc            _conds   _dewptm   _fog   _hail  \
# 246     19961113-08:00             Smoke      10.0      0       0
# 2494    19970301-09:00              Haze       8.0      0       0
# 2495    19970301-10:00              Haze       8.0      0       0
# 3197    19970408-09:00  Scattered Clouds      15.0      0       0
# 3198    19970408-10:00     Partly Cloudy      14.0      0       0
# ...                ...               ...       ...    ...     ...
# 100980  20170423-15:00              Haze      18.0      0       0
# 100985  20170424-06:00              Haze      17.0      0       0
# 100986  20170424-09:00              Haze      14.0      0       0
# 100987  20170424-12:00              Haze      12.0      0       0
# 100988  20170424-15:00              Haze      15.0      0       0
#
#          _heatindexm   _hum   _precipm   _pressurem   _rain   _snow   _tempm  \
# 246              0.0   23.0        0.0       1011.0       0       0     34.0
# ...

# %%
df[['datetime_utc',' _tempm']][df[' _tempm']==df[' _tempm'].max()]
# Out:
#          datetime_utc   _tempm
# 91391  20150624-03:00     90.0
